# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv('marine.csv')

# %%
data_df.head(10)
# Out:
#    Year  Age   Tm  Lg  W  L   W-L%   ERA   G  GS      ...        WP   BF  \
# 0  1995   25  NYY  AL  5  3  0.625  5.51  19  10      ...         0  301
# 1  1996   26  NYY  AL  8  3  0.727  2.09  61   0      ...         1  425
# 2  1997   27  NYY  AL  6  4  0.600  1.88  66   0      ...         2  301
# 3  1998   28  NYY  AL  3  0  1.000  1.91  54   0      ...         0  246
# 4  1999   29  NYY  AL  4  3  0.571  1.83  66   0      ...         2  268
# 5  2000   30  NYY  AL  7  4  0.636  2.85  66   0      ...         2  311
# 6  2001   31  NYY  AL  4  6  0.400  2.34  71   0      ...         1  310
# 7  2002   32  NYY  AL  1  4  0.200  2.74  45   0      ...         1  187
# 8  2003   33  NYY  AL  5  2  0.714  1.66  64   0      ...         0  277
# 9  2004   34  NYY  AL  4  2  0.667  1.94  74   0      ...         0  316
#
#    ERA+   WHIP  H/9  HR/9  BB/9  SO/9  SO/BB         Awards
# 0    84  1.507  9.5   1.5   4.0   6.9   1.70            NaN
# ...

# %%
data_df.to_excel("abc.xlsx",index=False)

# %%
data_from_excel = pd.read_excel("abc.xlsx")

# %%
data_from_excel.head()
# Out:
#    Year  Age   Tm  Lg  W  L   W-L%   ERA   G  GS      ...        WP   BF  \
# 0  1995   25  NYY  AL  5  3  0.625  5.51  19  10      ...         0  301
# 1  1996   26  NYY  AL  8  3  0.727  2.09  61   0      ...         1  425
# 2  1997   27  NYY  AL  6  4  0.600  1.88  66   0      ...         2  301
# 3  1998   28  NYY  AL  3  0  1.000  1.91  54   0      ...         0  246
# 4  1999   29  NYY  AL  4  3  0.571  1.83  66   0      ...         2  268
#
#    ERA+   WHIP  H/9  HR/9  BB/9  SO/9  SO/BB         Awards
# 0    84  1.507  9.5   1.5   4.0   6.9   1.70            NaN
# 1   240  0.994  6.1   0.1   2.8  10.9   3.82    CYA-3MVP-12
# 2   239  1.186  8.2   0.6   2.5   8.5   3.40       ASMVP-25
# 3   233  1.060  7.0   0.4   2.5   5.3   2.12            NaN
# 4   257  0.884  5.6   0.3   2.3   6.8   2.89  ASCYA-3MVP-14
#
# [5 rows x 34 columns]

# %%
val = data_df['Year']

# %%
type(val)
# Out:
# pandas.core.series.Series

# %%
data_df.set_index('Year',inplace=True)

# %%
data_df.loc[[1998,2003,2004]]
# Out:
#       Age   Tm  Lg  W  L   W-L%   ERA   G  GS  GF      ...       WP   BF  \
# Year                                                   ...
# 1998   28  NYY  AL  3  0  1.000  1.91  54   0  49      ...        0  246
# 2003   33  NYY  AL  5  2  0.714  1.66  64   0  57      ...        0  277
# 2004   34  NYY  AL  4  2  0.667  1.94  74   0  69      ...        0  316
#
#       ERA+   WHIP  H/9  HR/9  BB/9  SO/9  SO/BB        Awards
# Year
# 1998   233  1.060  7.0   0.4   2.5   5.3   2.12           NaN
# 2003   267  1.005  7.8   0.4   1.3   8.0   6.30        MVP-27
# 2004   232  1.081  7.4   0.3   2.3   7.6   3.30  ASCYA-3MVP-9
#
# [3 rows x 33 columns]

# %%
my_data = pd.DataFrame({'key':range(10),'value':range(10,20)})

# %%
my_data
# Out:
#    key  value
# 0    0     10
# 1    1     11
# 2    2     12
# 3    3     13
# 4    4     14
# 5    5     15
# 6    6     16
# 7    7     17
# 8    8     18
# 9    9     19

# %%
my_data2= pd.DataFrame({'key':range(0,20,2),'value':range(10,30,2)})

# %%
my_data2
# Out:
#    key  value
# 0    0     10
# 1    2     12
# 2    4     14
# 3    6     16
# 4    8     18
# 5   10     20
# 6   12     22
# 7   14     24
# 8   16     26
# 9   18     28

# %%
merged=my_data.merge(my_data2,on='key',how='outer')

# %%
merged
# Out:
#      key  value_x  value_y
# 0    0.0     10.0     10.0
# 1    1.0     11.0      NaN
# 2    2.0     12.0     12.0
# 3    3.0     13.0      NaN
# 4    4.0     14.0     14.0
# 5    5.0     15.0      NaN
# 6    6.0     16.0     16.0
# 7    7.0     17.0      NaN
# 8    8.0     18.0     18.0
# 9    9.0     19.0      NaN
# 10  10.0      NaN     20.0
# 11  12.0      NaN     22.0
# 12  14.0      NaN     24.0
# 13  16.0      NaN     26.0
# 14  18.0      NaN     28.0

# %%
my_data.merge(my_data2,how='right',on='key')
# Out:
#     key  value_x  value_y
# 0   0.0     10.0       10
# 1   2.0     12.0       12
# 2   4.0     14.0       14
# 3   6.0     16.0       16
# 4   8.0     18.0       18
# 5  10.0      NaN       20
# 6  12.0      NaN       22
# 7  14.0      NaN       24
# 8  16.0      NaN       26
# 9  18.0      NaN       28

# %%
pd.concat([my_data,my_data2],axis=0,join='outer',verify_integrity=True,ignore_index=True,)
# Out:
#     key  value
# 0     0     10
# 1     1     11
# 2     2     12
# 3     3     13
# 4     4     14
# 5     5     15
# 6     6     16
# 7     7     17
# 8     8     18
# 9     9     19
# 10    0     10
# 11    2     12
# 12    4     14
# 13    6     16
# 14    8     18
# 15   10     20
# 16   12     22
# 17   14     24
# 18   16     26
# 19   18     28

# %%
print "ghelfhdsklfdskjf"
# Out:
# ghelfhdsklfdskjf

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.scatter([1,2,3,4],[3,4,5,6])

# %%
for i in range(100):
    print "hello"
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
